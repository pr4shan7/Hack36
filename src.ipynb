# %%
import pandas as pd
import numpy as np
import folium

# %%
data=pd.read_csv('201803-fordgobike-tripdata.csv')

# %%
data.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         71766  2018-03-31 16:58:33.1490  2018-04-01 12:54:39.2630
# 1         62569  2018-03-31 19:03:35.9160  2018-04-01 12:26:25.0350
# 2         56221  2018-03-31 20:13:13.5640  2018-04-01 11:50:14.8400
# 3         85844  2018-03-31 11:28:07.6580  2018-04-01 11:18:52.6130
# 4          1566  2018-03-31 23:37:56.6400  2018-04-01 00:04:02.8930
#
#    start_station_id            start_station_name  start_station_latitude  \
# 0                 4   Cyril Magnin St at Ellis St               37.785881
# 1                78           Folsom St at 9th St               37.773717
# 2               258   University Ave at Oxford St               37.872355
# 3               186        Lakeside Dr at 14th St               37.801319
# 4               193  Grand Ave at Santa Clara Ave               37.812744
#
#    start_station_longitude  end_station_id               end_station_name  \
# ...

# %%
def generateBaseMap(default_location=[40.693943, -73.985880], default_zoom_start=12):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

import matplotlib.pyplot as plt
import folium
from folium import plugins
from folium.plugins import HeatMap
df_copy = data.copy()
df_copy['count'] = 1
base_map = generateBaseMap()
HeatMap(data=df_copy[['start_station_latitude', 'start_station_longitude', 'count']].groupby(['start_station_latitude', 'start_station_longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(base_map)

# %%
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
data['start_time'] = pd.to_datetime(data['start_time'])
data['start_Date'], data['start_Time'] = data['start_time'].dt.normalize(), data['start_time'].dt.time

data['end_time'] = pd.to_datetime(data['end_time'])
data['end_Date'], data['end_Time'] = data['end_time'].dt.normalize(), data['end_time'].dt.time

# %%
data.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         71766 2018-03-31 16:58:33.149 2018-04-01 12:54:39.263
# 1         62569 2018-03-31 19:03:35.916 2018-04-01 12:26:25.035
# 2         56221 2018-03-31 20:13:13.564 2018-04-01 11:50:14.840
# 3         85844 2018-03-31 11:28:07.658 2018-04-01 11:18:52.613
# 4          1566 2018-03-31 23:37:56.640 2018-04-01 00:04:02.893
#
#    start_station_id            start_station_name  start_station_latitude  \
# 0                 4   Cyril Magnin St at Ellis St               37.785881
# 1                78           Folsom St at 9th St               37.773717
# 2               258   University Ave at Oxford St               37.872355
# 3               186        Lakeside Dr at 14th St               37.801319
# 4               193  Grand Ave at Santa Clara Ave               37.812744
#
#    start_station_longitude  end_station_id               end_station_name  \
# ...

# %%
def get_hour(dt):
    return dt.hour

data['hour'] = data['start_Time'].map(get_hour)

# %%
data.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         71766 2018-03-31 16:58:33.149 2018-04-01 12:54:39.263
# 1         62569 2018-03-31 19:03:35.916 2018-04-01 12:26:25.035
# 2         56221 2018-03-31 20:13:13.564 2018-04-01 11:50:14.840
# 3         85844 2018-03-31 11:28:07.658 2018-04-01 11:18:52.613
# 4          1566 2018-03-31 23:37:56.640 2018-04-01 00:04:02.893
#
#    start_station_id            start_station_name  start_station_latitude  \
# 0                 4   Cyril Magnin St at Ellis St               37.785881
# 1                78           Folsom St at 9th St               37.773717
# 2               258   University Ave at Oxford St               37.872355
# 3               186        Lakeside Dr at 14th St               37.801319
# 4               193  Grand Ave at Santa Clara Ave               37.812744
#
#    start_station_longitude  end_station_id               end_station_name  \
# ...

# %%
for i in range(0,24,4):
    data['count']=i

# %%
data.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         71766 2018-03-31 16:58:33.149 2018-04-01 12:54:39.263
# 1         62569 2018-03-31 19:03:35.916 2018-04-01 12:26:25.035
# 2         56221 2018-03-31 20:13:13.564 2018-04-01 11:50:14.840
# 3         85844 2018-03-31 11:28:07.658 2018-04-01 11:18:52.613
# 4          1566 2018-03-31 23:37:56.640 2018-04-01 00:04:02.893
#
#    start_station_id            start_station_name  start_station_latitude  \
# 0                 4   Cyril Magnin St at Ellis St               37.785881
# 1                78           Folsom St at 9th St               37.773717
# 2               258   University Ave at Oxford St               37.872355
# 3               186        Lakeside Dr at 14th St               37.801319
# 4               193  Grand Ave at Santa Clara Ave               37.812744
#
#    start_station_longitude  end_station_id               end_station_name  \
# ...

# %%
data.drop(['count'], axis=1)
# Out:
#         duration_sec              start_time                end_time  \
# 0              71766 2018-03-31 16:58:33.149 2018-04-01 12:54:39.263
# 1              62569 2018-03-31 19:03:35.916 2018-04-01 12:26:25.035
# 2              56221 2018-03-31 20:13:13.564 2018-04-01 11:50:14.840
# 3              85844 2018-03-31 11:28:07.658 2018-04-01 11:18:52.613
# 4               1566 2018-03-31 23:37:56.640 2018-04-01 00:04:02.893
# 5                281 2018-03-31 23:58:07.805 2018-04-01 00:02:49.359
# 6                896 2018-03-31 23:47:48.797 2018-04-01 00:02:45.538
# 7                440 2018-03-31 23:51:17.800 2018-03-31 23:58:38.712
# 8                169 2018-03-31 23:50:43.814 2018-03-31 23:53:33.571
# 9               2765 2018-03-31 23:03:50.016 2018-03-31 23:49:55.319
# 10              2756 2018-03-31 23:03:50.969 2018-03-31 23:49:47.488
# 11               511 2018-03-31 23:40:34.552 2018-03-31 23:49:06.402
# 12               419 2018-03-31 23:42:01.166 2018-03-31 23:49:00.727
# ...

# %%
data_hour=data.groupby(['hour'])

# %%
data_hour.count()
# Out:
#       duration_sec  start_time  end_time  start_station_id  \
# hour
# 0              538         538       538               538
# 1              273         273       273               273
# 2              162         162       162               162
# 3              123         123       123               123
# 4              182         182       182               182
# 5              488         488       488               488
# 6             1924        1924      1924              1924
# 7             5640        5640      5640              5640
# 8            12460       12460     12460             12460
# 9             9800        9800      9800              9800
# 10            4878        4878      4878              4878
# 11            4601        4601      4601              4601
# 12            5494        5494      5494              5494
# 13            5365        5365      5365              5365
# 14            5167        5167      5167              5167
# ...

# %%
data_loc=data.groupby(['start_station_id'])

# %%
data_hour_0to4 = data[data['hour']<4]

# %%
data_hour_0to4
# Out:
#         duration_sec              start_time                end_time  \
# 2604             597 2018-03-31 03:42:24.733 2018-03-31 03:52:22.293
# 2605             535 2018-03-31 03:05:16.232 2018-03-31 03:14:11.448
# 2606             574 2018-03-31 03:02:34.236 2018-03-31 03:12:08.718
# 2607             552 2018-03-31 03:02:54.722 2018-03-31 03:12:06.937
# 2608             994 2018-03-31 02:52:11.699 2018-03-31 03:08:46.152
# 2609            3115 2018-03-31 02:02:10.190 2018-03-31 02:54:05.464
# 2610             664 2018-03-31 02:40:56.990 2018-03-31 02:52:01.200
# 2611             178 2018-03-31 02:47:04.566 2018-03-31 02:50:02.736
# 2612             231 2018-03-31 02:43:53.893 2018-03-31 02:47:45.027
# 2613            4543 2018-03-31 01:14:54.747 2018-03-31 02:30:38.114
# 2614            4535 2018-03-31 01:15:00.363 2018-03-31 02:30:35.740
# 2615            4387 2018-03-31 01:17:23.677 2018-03-31 02:30:31.115
# 2616            4430 2018-03-31 01:16:32.114 2018-03-31 02:30:22.535
# ...

# %%
hour_4t8=[4,5,6,7]
data_hour_4to8 = data[data['hour'].isin(hour_4t8)]

# %%
data_hour_4to8
# Out:
#         duration_sec              start_time                end_time  \
# 2340           14515 2018-03-31 06:14:15.269 2018-03-31 10:16:11.143
# 2448            6786 2018-03-31 07:29:46.488 2018-03-31 09:22:52.562
# 2513            3069 2018-03-31 07:47:51.618 2018-03-31 08:39:01.045
# 2515            2639 2018-03-31 07:51:42.155 2018-03-31 08:35:41.556
# 2526            1855 2018-03-31 07:53:53.471 2018-03-31 08:24:48.906
# 2537            2176 2018-03-31 07:32:33.916 2018-03-31 08:08:50.606
# 2540            1048 2018-03-31 07:49:04.204 2018-03-31 08:06:32.471
# 2542             638 2018-03-31 07:51:31.225 2018-03-31 08:02:09.574
# 2543             609 2018-03-31 07:50:46.262 2018-03-31 08:00:55.571
# 2544             256 2018-03-31 07:55:41.094 2018-03-31 07:59:57.361
# 2545             648 2018-03-31 07:49:07.919 2018-03-31 07:59:56.483
# 2546             661 2018-03-31 07:47:44.770 2018-03-31 07:58:46.119
# 2547             323 2018-03-31 07:53:12.723 2018-03-31 07:58:36.247
# ...

# %%
hour_8t12=[8,9,10,11]
data_hour_8t12 = data[data['hour'].isin(hour_8t12)]

# %%
hour_12t16=[12,13,14,15]
data_hour_12t16 = data[data['hour'].isin(hour_12t16)]

# %%
hour_16t20=[16,17,18,19]
data_hour_16t20 = data[data['hour'].isin(hour_16t20)]

# %%
hour_20t24=[20,21,22,23]
data_hour_20t24 = data[data['hour'].isin(hour_20t24)]

# %%
def generateBaseMap(default_location=[37.785881, -122.408915], default_zoom_start=12):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

import matplotlib.pyplot as plt
import folium
from folium import plugins
from folium.plugins import HeatMap
df_copy = data_hour_0to4.copy()
df_copy['count'] = 1
base_map = generateBaseMap()
HeatMap(data=df_copy[['start_station_latitude', 'start_station_longitude', 'count']].groupby(['start_station_latitude', 'start_station_longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(base_map)

# %%
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
def generateBaseMap(default_location=[37.785881, -122.408915], default_zoom_start=12):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

import matplotlib.pyplot as plt
import folium
from folium import plugins
from folium.plugins import HeatMap
df_copy = data_hour_4to8.copy()
df_copy['count'] = 1
base_map = generateBaseMap()
HeatMap(data=df_copy[['start_station_latitude', 'start_station_longitude', 'count']].groupby(['start_station_latitude', 'start_station_longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(base_map)

# %%
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
def generateBaseMap(default_location=[37.785881, -122.408915], default_zoom_start=12):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

import matplotlib.pyplot as plt
import folium
from folium import plugins
from folium.plugins import HeatMap
df_copy = data_hour_8t12.copy()
df_copy['count'] = 1
base_map = generateBaseMap()
HeatMap(data=df_copy[['start_station_latitude', 'start_station_longitude', 'count']].groupby(['start_station_latitude', 'start_station_longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(base_map)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
def generateBaseMap(default_location=[37.785881, -122.408915], default_zoom_start=12):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

import matplotlib.pyplot as plt
import folium
from folium import plugins
from folium.plugins import HeatMap
df_copy = data_hour_12t16.copy()
df_copy['count'] = 1
base_map = generateBaseMap()
HeatMap(data=df_copy[['start_station_latitude', 'start_station_longitude', 'count']].groupby(['start_station_latitude', 'start_station_longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(base_map)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
def generateBaseMap(default_location=[37.785881, -122.408915], default_zoom_start=12):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

import matplotlib.pyplot as plt
import folium
from folium import plugins
from folium.plugins import HeatMap
df_copy = data_hour_16t20.copy()
df_copy['count'] = 1
base_map = generateBaseMap()
HeatMap(data=df_copy[['start_station_latitude', 'start_station_longitude', 'count']].groupby(['start_station_latitude', 'start_station_longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(base_map)

base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
def generateBaseMap(default_location=[37.785881, -122.408915], default_zoom_start=12):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

import matplotlib.pyplot as plt
import folium
from folium import plugins
from folium.plugins import HeatMap
df_copy = data_hour_20t24.copy()
df_copy['count'] = 1
base_map = generateBaseMap()
HeatMap(data=df_copy[['start_station_latitude', 'start_station_longitude', 'count']].groupby(['start_station_latitude', 'start_station_longitude']).sum().reset_index().values.tolist(), radius=8, max_zoom=13).add_to(base_map)

base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
data.drop(['count'], axis=1)
# Out:
#         duration_sec              start_time                end_time  \
# 0              71766 2018-03-31 16:58:33.149 2018-04-01 12:54:39.263
# 1              62569 2018-03-31 19:03:35.916 2018-04-01 12:26:25.035
# 2              56221 2018-03-31 20:13:13.564 2018-04-01 11:50:14.840
# 3              85844 2018-03-31 11:28:07.658 2018-04-01 11:18:52.613
# 4               1566 2018-03-31 23:37:56.640 2018-04-01 00:04:02.893
# 5                281 2018-03-31 23:58:07.805 2018-04-01 00:02:49.359
# 6                896 2018-03-31 23:47:48.797 2018-04-01 00:02:45.538
# 7                440 2018-03-31 23:51:17.800 2018-03-31 23:58:38.712
# 8                169 2018-03-31 23:50:43.814 2018-03-31 23:53:33.571
# 9               2765 2018-03-31 23:03:50.016 2018-03-31 23:49:55.319
# 10              2756 2018-03-31 23:03:50.969 2018-03-31 23:49:47.488
# 11               511 2018-03-31 23:40:34.552 2018-03-31 23:49:06.402
# 12               419 2018-03-31 23:42:01.166 2018-03-31 23:49:00.727
# ...

# %%
data['DayOfWeekNum'] =data['start_Date'].dt.dayofweek

# %%
data_by_week_days=data.groupby(['DayOfWeekNum'])

# %%
data_by_week_days.count()
# Out:
#               duration_sec  start_time  end_time  start_station_id  \
# DayOfWeekNum
# 0                    17855       17855     17855             17855
# 1                    15743       15743     15743             15743
# 2                    18417       18417     18417             18417
# 3                    19985       19985     19985             19985
# 4                    19904       19904     19904             19904
# 5                    11026       11026     11026             11026
# 6                     8452        8452      8452              8452
#
#               start_station_name  start_station_latitude  \
# DayOfWeekNum
# 0                          17855                   17855
# 1                          15743                   15743
# 2                          18417                   18417
# 3                          19985                   19985
# 4                          19904                   19904
# ...

# %%
from folium.plugins import MarkerCluster
m = folium.Map(location=[51.5, -0.1], zoom_start=10)

locations = list(zip(data_hour_0to4.start_station_latitude, data_hour_0to4.start_station_longitude))
icons = [folium.Icon(icon="car", prefix="fa") for _ in range(len(locations))]

cluster = MarkerCluster(locations=locations, icons=icons)
m.add_child(cluster)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
data_hour_0t4_dstn=data_hour_0to4

# %%
map_for_dstn_0t4 = folium.Map(location=[51.5, -0.1], zoom_start=10)

locations = list(zip(data_hour_0t4_dstn.end_station_latitude, data_hour_0t4_dstn.end_station_longitude))
icons = [folium.Icon(icon="car", prefix="fa") for _ in range(len(locations))]

cluster = MarkerCluster(locations=locations, icons=icons)
map_for_dstn_0t4.add_child(cluster)
map_for_dstn_0t4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
#similarly we can do for other sectors of time and compare with pickups point
